# %%
import pandas as pd

# %%
df1 = pd.read_excel('FinancialSample.xlsx','Sheet1')

# %%
df2 = pd.read_excel('FinancialSample.xlsx','Sheet2')

# %%
df1.head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera          None      1618.5
# 1  Government  Germany  Carretera          None      1321.0
# 2   Midmarket   France  Carretera          None      2178.0
# 3   Midmarket  Germany  Carretera          None       888.0
# 4   Midmarket   Mexico  Carretera          None      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
# 2                    3          15      32670.0        0.0  32670.0  21780.0
# 3                    3          15      13320.0        0.0  13320.0   8880.0
# 4                    3          15      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  Year
# 0  16185.0 2014-01-01             1    January  2014
# ...

# %%
#Find average profit for each product
filtered_df = df1[['Product','Profit',' Sales']]
#filtered_df.head()
filtered_df.groupby('Product').agg('mean')
# Out:
#                  Profit          Sales
# Product
# Amarilla   29937.277234  188799.107021
# Carretera  19643.063280  148551.697688
# Montana    22739.299785  165492.493333
# Paseo      23749.692822  163421.504703
# VTT        27840.440550  188182.761651
# Velo       21155.894174  167431.738211

# %%
#Find the total sales of Carretera in Maxico
df1[(df1['Country'] == 'Mexico') & (df1['Product'] == 'Carretera')][' Sales'].sum()
# Out:
# 2879601.42

# %%
#df1[(df1['Country'] == 'Canada') | (df1['Country'] == 'Germany')]

df1[df1['Country'].isin(['Canada','Germany'])].head(2)
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera          None      1618.5
# 1  Government  Germany  Carretera          None      1321.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
#
#     Profit       Date  Month Number Month Name  Year
# 0  16185.0 2014-01-01             1    January  2014
# 1  13210.0 2014-01-01             1    January  2014

# %%
# Filter data for Contry either 'Canada' or 'Germany' and only for product 'Carretera' where profit >5000

df1[(df1['Country'].isin(['Canada','Germany'])) & (df1['Product'] == 'Carretera') & (df1['Profit']>5000.0)].head()
# Out:
#              Segment  Country    Product Discount Band  Units Sold  \
# 0         Government   Canada  Carretera          None      1618.5
# 1         Government  Germany  Carretera          None      1321.0
# 5         Government  Germany  Carretera          None      1513.0
# 61  Channel Partners   Canada  Carretera           Low      1445.0
# 64  Channel Partners  Germany  Carretera           Low       766.0
#
#     Manufacturing Price  Sale Price  Gross Sales  Discounts      Sales  \
# 0                     3          20      32370.0       0.00   32370.00
# 1                     3          20      26420.0       0.00   26420.00
# 5                     3         350     529550.0       0.00  529550.00
# 61                    3          12      17340.0     173.40   17166.60
# 64                    3          12       9192.0      91.92    9100.08
#
#         COGS     Profit       Date  Month Number Month Name  Year
# 0    16185.0   16185.00 2014-01-01             1    January  2014
# ...

# %% [markdown]
# #Joining 2 dataframes

# %% [markdown]
# #(1) Horizontally Join

# %%
part1 = df1[df1['Country'] == 'Canada']
part2 = df1[df1['Country'] == 'Germany']

# %%
part1.head()
# Out:
#              Segment Country    Product Discount Band  Units Sold  \
# 0         Government  Canada  Carretera          None      1618.5
# 7   Channel Partners  Canada    Montana          None      2518.0
# 11        Enterprise  Canada    Montana          None      2665.5
# 14        Enterprise  Canada    Montana          None       345.0
# 16        Government  Canada      Paseo          None       292.0
#
#     Manufacturing Price  Sale Price  Gross Sales  Discounts     Sales  \
# 0                     3          20      32370.0        0.0   32370.0
# 7                     5          12      30216.0        0.0   30216.0
# 11                    5         125     333187.5        0.0  333187.5
# 14                    5         125      43125.0        0.0   43125.0
# 16                   10          20       5840.0        0.0    5840.0
#
#         COGS   Profit       Date  Month Number Month Name  Year
# 0    16185.0  16185.0 2014-01-01             1    January  2014
# ...

# %%
part2.head()
# Out:
#             Segment  Country    Product Discount Band  Units Sold  \
# 1        Government  Germany  Carretera          None      1321.0
# 3         Midmarket  Germany  Carretera          None       888.0
# 5        Government  Germany  Carretera          None      1513.0
# 6         Midmarket  Germany    Montana          None       921.0
# 9  Channel Partners  Germany    Montana          None      1545.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts     Sales  \
# 1                    3          20      26420.0        0.0   26420.0
# 3                    3          15      13320.0        0.0   13320.0
# 5                    3         350     529550.0        0.0  529550.0
# 6                    5          15      13815.0        0.0   13815.0
# 9                    5          12      18540.0        0.0   18540.0
#
#        COGS    Profit       Date  Month Number Month Name  Year
# 1   13210.0   13210.0 2014-01-01             1    January  2014
# ...

# %%
df_concated = pd.concat([part1,part2], axis = 0)

# %%
df_concated
# Out:
#               Segment  Country    Product Discount Band  Units Sold  \
# 0          Government   Canada  Carretera          None      1618.5
# 7    Channel Partners   Canada    Montana          None      2518.0
# 11         Enterprise   Canada    Montana          None      2665.5
# 14         Enterprise   Canada    Montana          None       345.0
# 16         Government   Canada      Paseo          None       292.0
# ..                ...      ...        ...           ...         ...
# 676        Enterprise  Germany      Paseo          High      1085.0
# 677         Midmarket  Germany      Paseo          High      1175.0
# 689         Midmarket  Germany        VTT          High       492.0
# 691         Midmarket  Germany        VTT          High      1175.0
# 693        Enterprise  Germany        VTT          High       552.0
#
#      Manufacturing Price  Sale Price  Gross Sales  Discounts      Sales  \
# 0                      3          20      32370.0       0.00   32370.00
# ...

# %% [markdown]
# #(2) Verticall Join
# Segment	Country	Product	Discount Band	Units Sold	Manufacturing Price	Sale Price	Gross Sales	Discounts	Sales	COGS

# %%
part3 = df[['Segment','Country','Product']]

# %%
part3.head()
# Out:
#       Segment  Country    Product
# 0  Government   Canada  Carretera
# 1  Government  Germany  Carretera
# 2   Midmarket   France  Carretera
# 3   Midmarket  Germany  Carretera
# 4   Midmarket   Mexico  Carretera

# %%
part4 = df[[' Sales','COGS']]
part4.head()
# Out:
#      Sales     COGS
# 0  32370.0  16185.0
# 1  26420.0  13210.0
# 2  32670.0  21780.0
# 3  13320.0   8880.0
# 4  37050.0  24700.0

# %%
df_concated = pd.concat([part3,part4], axis = 1)

# %%
df_concated.head()
# Out:
#       Segment  Country    Product    Sales     COGS
# 0  Government   Canada  Carretera  32370.0  16185.0
# 1  Government  Germany  Carretera  26420.0  13210.0
# 2   Midmarket   France  Carretera  32670.0  21780.0
# 3   Midmarket  Germany  Carretera  13320.0   8880.0
# 4   Midmarket   Mexico  Carretera  37050.0  24700.0

# %% [markdown]
# #Aggregate functions with groupby

# %%
filtered = df_concated[['Product','COGS']]

# %%
x = filtered.groupby('Product').agg('mean')

# %%
x
# Out:
#                     COGS
# Product
# Amarilla   158861.829787
# Carretera  128908.634409
# Montana    142753.193548
# Paseo      139671.811881
# VTT        160342.321101
# Velo       146275.844037

# %%
# Filter data with segment and sale.
# Find maximum sales for each segment.

# %%
tempdf = df1[['Segment',' Sales']]

# %%
tempdf.head()
# Out:
#       Segment    Sales
# 0  Government  32370.0
# 1  Government  26420.0
# 2   Midmarket  32670.0
# 3   Midmarket  13320.0
# 4   Midmarket  37050.0

# %%
tempdf.groupby('Segment').agg('max')
# Out:
#                        Sales
# Segment
# Channel Partners    42997.68
# Enterprise         527437.50
# Government        1159200.00
# Midmarket           53594.10
# Small Business    1038082.50
