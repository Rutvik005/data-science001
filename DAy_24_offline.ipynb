# %%
import pandas as pd

# %%
df = pd.read_csv('Social_Network_Ads.csv')

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
del df['User ID']

# %%
from sklearn import preprocessing
  

label_encoder = preprocessing.LabelEncoder()
  
df['Gender']= label_encoder.fit_transform(df['Gender'])
  
df['Gender'].unique()
# Out:
# array([1, 0])

# %%
df.head()
# Out:
#    Gender  Age  EstimatedSalary  Purchased
# 0       1   19            19000          0
# 1       1   35            20000          0
# 2       0   26            43000          0
# 3       0   27            57000          0
# 4       1   19            76000          0

# %%
# from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler()

# df[["EstimatedSalary_StandardScalled"]] = scaler.fit_transform(df[["EstimatedSalary"]])

# df[["Age_StandardScalled"]] = scaler.fit_transform(df[["Age"]])

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

df[["Age_MinMaxScalled"]] = scaler.fit_transform(df[["Age"]])

# %%
df[["EstimatedSalary_MinMaxScalled"]] = scaler.fit_transform(df[["EstimatedSalary"]])

# %%
x = df[['Gender','Age_MinMaxScalled','EstimatedSalary_MinMaxScalled']]
y = df['Purchased']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# --------------------------------------

# %% [markdown]
# #RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier(max_depth=2)
clf.fit(X_train, y_train)
pred=clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
accuracy_score(y_test,pred)
# Out:
# 0.95

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score

max = [i for i in range(3,21)]
min = [i for i in range(3,10)]
ast = [50,100,150,200,250,300,350,400,450,500]
    
for k in ast:
  for i in max:
    for j in min:
    
      clf = RandomForestClassifier(max_depth=i,min_samples_leaf=j,n_estimators=k)
      clf.fit(X_train, y_train)
      pred=clf.predict(X_test)
      a = accuracy_score(y_test,pred)
      print(a,i,j,k)
# Out:
# 0.95 3 3 50
# 0.95 3 4 50
# 0.95 3 5 50
# 0.95 3 6 50
# 0.95 3 7 50
# 0.95 3 8 50
# 0.95 3 9 50
# 0.95 4 3 50
# 0.95 4 4 50
# 0.95 4 5 50
# 0.95 4 6 50
# 0.95 4 7 50
# 0.95 4 8 50
# 0.95 4 9 50
# 0.95 5 3 50
# 0.95 5 4 50
# 0.95 5 5 50
# 0.95 5 6 50
# 0.95 5 7 50
# 0.95 5 8 50
# 0.95 5 9 50
# 0.95 6 3 50
# 0.95 6 4 50
# 0.95 6 5 50
# 0.95 6 6 50
# 0.95 6 7 50
# 0.95 6 8 50
# 0.95 6 9 50
# 0.95 7 3 50
# 0.95 7 4 50
# 0.95 7 5 50
# 0.95 7 6 50
# 0.95 7 7 50
# 0.95 7 8 50
# 0.95 7 9 50
# 0.95 8 3 50
# 0.95 8 4 50
# 0.95 8 5 50
# 0.95 8 6 50
# 0.95 8 7 50
# 0.95 8 8 50
# 0.95 8 9 50
# 0.95 9 3 50
# 0.95 9 4 50
# 0.95 9 5 50
# 0.95 9 6 50
# 0.95 9 7 50
# 0.95 9 8 50
# 0.95 9 9 50
# 0.95 10 3 50
# 0.95 10 4 50
# 0.95 10 5 50
# 0.95 10 6 50
# 0.95 10 7 50
# 0.95 10 8 50
# 0.95 10 9 50
# 0.95 11 3 50
# 0.95 11 4 50
# 0.95 11 5 50
# 0.95 11 6 50
# 0.95 11 7 50
# 0.95 11 8 50
# 0.95 11 9 50
# 0.95 12 3 50
# 0.95 12 4 50
# 0.95 12 5 50
# 0.95 12 6 50
# 0.95 12 7 50
# 0.95 12 8 50
# ...

# %% [markdown]
# #SVM

# %%
from sklearn.svm import SVC

# %%
clf = SVC()
clf.fit(X_train, y_train)
pred=clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
accuracy_score(y_test,pred)
# Out:
# 0.9375
