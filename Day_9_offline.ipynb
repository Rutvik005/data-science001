# %%
import pandas as pd

# %%
df = pd.read_excel('FinancialSample.xlsx','Sheet1')

# %%
df.isna().sum()
# Out:
# Segment                  0
# Country                  0
# Product                  0
# Discount Band            0
# Units Sold               0
# Manufacturing Price      0
# Sale Price               0
# Gross Sales              0
# Discounts                0
#  Sales                   0
# COGS                    28
# Profit                 137
# Date                    14
# Month Number             0
# Month Name               0
# Year                     0
# dtype: int64

# %%
df.isna().mean()
# Out:
# Segment                0.000000
# Country                0.000000
# Product                0.000000
# Discount Band          0.000000
# Units Sold             0.000000
# Manufacturing Price    0.000000
# Sale Price             0.000000
# Gross Sales            0.000000
# Discounts              0.000000
#  Sales                 0.000000
# COGS                   0.040000
# Profit                 0.195714
# Date                   0.020000
# Month Number           0.000000
# Month Name             0.000000
# Year                   0.000000
# dtype: float64

# %% [markdown]
# Drop rows where perticular colum is null pandas dataframe

# %%
df1 = df[df['COGS'].notna()]

# %%
df2 = df.dropna(subset=["COGS"])

# %% [markdown]
# #Operation between 2 columns

# %%
df.head()
# Out:
#       Segment       Country    Product Discount Band  Units Sold  \
# 0  Government   CanadaIndia  Carretera          None      1618.5
# 1  Government  GermanyIndia  Carretera          None      1321.0
# 2   Midmarket   FranceIndia  Carretera          None      2178.0
# 3   Midmarket  GermanyIndia  Carretera          None       888.0
# 4   Midmarket   MexicoIndia  Carretera          None      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
# 2                    3          15      32670.0        0.0  32670.0  21780.0
# 3                    3          15      13320.0        0.0  13320.0   8880.0
# 4                    3          15      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  Year               New_column  \
# ...

# %%
df['New_column'] = df['Segment'] + '______' + df['Country']

# %%
df['Country'] = df['Country'] + "India"

# %%
# Ratio :  ratio of profit and sales columns
df['Ratio'] = df['Profit']/df[' Sales']

# %% [markdown]
# #Apply external method

# %%
def find_length(st):
  l = len(st)
  return(l)

# %%
df['length'] = df['Segment'].apply(find_length)

# %%
df.head()
# Out:
#       Segment       Country    Product Discount Band  Units Sold  \
# 0  Government   CanadaIndia  Carretera          None      1618.5
# 1  Government  GermanyIndia  Carretera          None      1321.0
# 2   Midmarket   FranceIndia  Carretera          None      2178.0
# 3   Midmarket  GermanyIndia  Carretera          None       888.0
# 4   Midmarket   MexicoIndia  Carretera          None      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
# 2                    3          15      32670.0        0.0  32670.0  21780.0
# 3                    3          15      13320.0        0.0  13320.0   8880.0
# 4                    3          15      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  Year               New_column  \
# ...

# %%
# Filter data with Product 'Paseo' and 'VTT'
#Find total null counts for each column. Drop a column who have highest nulls
#Filter data with Canada country only
#Perform group by on segment  column to find maximum sales

# %%
x1 = df[df['Product'].isin(['Paseo','VTT'])]

# %%
x1.isna().sum()
# Out:
# Segment                 0
# Country                 0
# Product                 0
# Discount Band           0
# Units Sold              0
# Manufacturing Price     0
# Sale Price              0
# Gross Sales             0
# Discounts               0
#  Sales                  0
# COGS                   19
# Profit                 66
# Date                   11
# Month Number            0
# Month Name              0
# Year                    0
# New_column              0
# Ratio                  66
# length                  0
# dtype: int64

# %%
del x1['Profit'],x1['Ratio']

# %%
x1.head()
# Out:
#              Segment       Country Product Discount Band  Units Sold  \
# 16        Government   CanadaIndia   Paseo          None       292.0
# 17         Midmarket   MexicoIndia   Paseo          None       974.0
# 18  Channel Partners   CanadaIndia   Paseo          None      2518.0
# 19        Government  GermanyIndia   Paseo          None      1006.0
# 20  Channel Partners  GermanyIndia   Paseo          None       367.0
#
#     Manufacturing Price  Sale Price  Gross Sales  Discounts     Sales  \
# 16                   10          20       5840.0        0.0    5840.0
# 17                   10          15      14610.0        0.0   14610.0
# 18                   10          12      30216.0        0.0   30216.0
# 19                   10         350     352100.0        0.0  352100.0
# 20                   10          12       4404.0        0.0    4404.0
#
#         COGS       Date  Month Number Month Name  Year  \
# 16    2920.0 2014-02-01             2   February  2014
# ...

# %%
x1[x1['Country'] == 'CanadaIndia']
# Out:
#               Segment      Country Product Discount Band  Units Sold  \
# 16         Government  CanadaIndia   Paseo          None       292.0
# 18   Channel Partners  CanadaIndia   Paseo          None      2518.0
# 26         Government  CanadaIndia   Paseo          None      1725.0
# 28          Midmarket  CanadaIndia   Paseo          None      2152.0
# 29         Government  CanadaIndia   Paseo          None      1817.0
# ..                ...          ...     ...           ...         ...
# 671         Midmarket  CanadaIndia   Paseo          High      1614.0
# 674         Midmarket  CanadaIndia   Paseo          High      2559.0
# 688        Government  CanadaIndia     VTT          High       865.5
# 692        Enterprise  CanadaIndia     VTT          High      2954.0
# 698        Government  CanadaIndia   Paseo          High       723.0
#
#      Manufacturing Price  Sale Price  Gross Sales  Discounts      Sales  \
# ...

# %%
x2 = x1[['Segment', ' Sales']]

# %%
x2.groupby('Segment').agg('max')
# Out:
#                        Sales
# Segment
# Channel Partners    42997.68
# Enterprise         408386.25
# Government        1159200.00
# Midmarket           53594.10
# Small Business     922680.00
